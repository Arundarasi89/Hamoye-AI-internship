# %%
import pandas as pd

# %%
#reading the csv file dataset
df = pd.read_csv('car data-Copy1.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (301, 9)

# %%
#works on series and dataframes
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.notna().sum()
# Out:
# Car_Name         301
# Year             301
# Selling_Price    301
# Present_Price    301
# Kms_Driven       301
# Fuel_Type        301
# Seller_Type      301
# Transmission     301
# Owner            301
# dtype: int64

# %%
#show the dataset, default value is 5
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
#show the dataset, first 6 rows, index starts from 0
df.head(7)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0

# %%
#information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
#statisitical table of dataset
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#indexing
#display values in fourth row using index 
#iloc - integer based
df.iloc[3]
# Out:
# Car_Name         wagon r
# Year                2011
# Selling_Price       2.85
# Present_Price       4.15
# Kms_Driven          5200
# Fuel_Type         Petrol
# Seller_Type       Dealer
# Transmission      Manual
# Owner                  0
# Name: 3, dtype: object

# %%
#display values in fourth row using index 
# loc - label based
df.loc[5]
# Out:
# Car_Name         vitara brezza
# Year                      2018
# Selling_Price             9.25
# Present_Price             9.83
# Kms_Driven                2071
# Fuel_Type               Diesel
# Seller_Type             Dealer
# Transmission            Manual
# Owner                        0
# Name: 5, dtype: object

# %%
#display values in rows 2,3, and 6 
df.loc[[2,3,6]]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 6     ciaz  2015           6.75           8.12       18796    Petrol
#
#   Seller_Type Transmission  Owner
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 6      Dealer       Manual      0

# %%
df.iloc[[0,4,9],[0,3,6]]
# Out:
#   Car_Name  Present_Price Seller_Type
# 0     ritz           5.59      Dealer
# 4    swift           6.87      Dealer
# 9     ciaz           8.92      Dealer

# %%
df.iloc[0:5,5:8]
# Out:
#   Fuel_Type Seller_Type Transmission
# 0    Petrol      Dealer       Manual
# 1    Diesel      Dealer       Manual
# 2    Petrol      Dealer       Manual
# 3    Petrol      Dealer       Manual
# 4    Diesel      Dealer       Manual

# %%
df.iloc[-1]
# Out:
# Car_Name           brio
# Year               2016
# Selling_Price       5.3
# Present_Price       5.9
# Kms_Driven         5464
# Fuel_Type        Petrol
# Seller_Type      Dealer
# Transmission     Manual
# Owner                 0
# Name: 300, dtype: object

# %%
df.loc[:,['Car_Name','Year']]
# Out:
#     Car_Name  Year
# 0       ritz  2014
# 1        sx4  2013
# 2       ciaz  2017
# 3    wagon r  2011
# 4      swift  2014
# ..       ...   ...
# 296     city  2016
# 297     brio  2015
# 298     city  2009
# 299     city  2017
# 300     brio  2016
#
# [301 rows x 2 columns]

# %%
df.loc[:,'Seller_Type'].head()
# Out:
# 0    Dealer
# 1    Dealer
# 2    Dealer
# 3    Dealer
# 4    Dealer
# Name: Seller_Type, dtype: object

# %%
#boolean indexing
df.loc[((df['Car_Name'] == 'swift') & (df['Seller_Type'] == 'Dealer')), 'Present_Price']
# Out:
# 4     6.87
# 25    4.99
# 26    5.87
# 32    7.49
# Name: Present_Price, dtype: float64

# %%
#slicing dataframe as if it were a list
df[:3]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
df[3:6]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0

# %%
#indexing with columns

# %%
df['Year'].head(3)
# Out:
# 0    2014
# 1    2013
# 2    2017
# Name: Year, dtype: int64

# %%
df.Year.head(2)
# Out:
# 0    2014
# 1    2013
# Name: Year, dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.columns = [col.replace(' ', '_').lower() for col in df.columns]
print(df.columns)
# Out:
# Index(['car_name', 'year', 'selling_price', 'present_price', 'kms_driven',
#        'fuel_type', 'seller_type', 'transmission', 'owner'],
#       dtype='object')

# %%
df[['car_name','year']][:4]
# Out:
#   car_name  year
# 0     ritz  2014
# 1      sx4  2013
# 2     ciaz  2017
# 3  wagon r  2011

# %%
#displays a single value 
df.present_price.iloc[1]
# Out:
# 9.54

# %%
#this diplays value with index
df.present_price.iloc[[2]]
# Out:
# 2    9.85
# Name: present_price, dtype: float64

# %%
(df.year == '2014').head(3)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# 0    False
# 1    False
# 2    False
# Name: year, dtype: bool

# %%
df[df.year == '2014']
# Out:
# Empty DataFrame
# Columns: [car_name, year, selling_price, present_price, kms_driven, fuel_type, seller_type, transmission, owner]
# Index: []

# %%
df[(df.selling_price > 10) | (df.present_price > 5)].head(6)
# Out:
#         car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0

# %%
df[df['car_name'].str.split().apply(lambda x: len(x) == 2)].head(5)
# Out:
#          car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# 18        wagon r  2015           3.25           5.09       35500       CNG
#
#    seller_type transmission  owner
# 3       Dealer       Manual      0
# 5       Dealer       Manual      0
# 7       Dealer       Manual      0
# 10      Dealer       Manual      0
# 18      Dealer       Manual      0

# %%
df[df.fuel_type.isin(['Petrol', 'Diesel'])].head()
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
values=['ritz',2014,3.35,5.59,27000,'Petrol','Dealer','Manual',0]

# %%
df_indexed=df.isin(values)


df_indexed.head(10)
# Out:
#    car_name   year  selling_price  present_price  kms_driven  fuel_type  \
# 0      True   True           True           True        True       True
# 1     False  False          False          False       False      False
# 2     False  False          False          False       False       True
# 3     False  False          False          False       False       True
# 4     False   True          False          False       False      False
# 5     False  False          False          False       False      False
# 6     False  False          False          False       False       True
# 7     False  False          False          False       False      False
# 8     False  False          False          False       False      False
# 9     False  False          False          False       False      False
#
#    seller_type  transmission  owner
# 0         True          True   True
# 1         True          True   True
# 2         True          True   True
# ...

# %%
#replacing values with nan where the condition df==0 is false
df_where=df.where(df == 0)

(df_where).head(10)
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0      NaN   NaN            NaN            NaN         NaN       NaN
# 1      NaN   NaN            NaN            NaN         NaN       NaN
# 2      NaN   NaN            NaN            NaN         NaN       NaN
# 3      NaN   NaN            NaN            NaN         NaN       NaN
# 4      NaN   NaN            NaN            NaN         NaN       NaN
# 5      NaN   NaN            NaN            NaN         NaN       NaN
# 6      NaN   NaN            NaN            NaN         NaN       NaN
# 7      NaN   NaN            NaN            NaN         NaN       NaN
# 8      NaN   NaN            NaN            NaN         NaN       NaN
# 9      NaN   NaN            NaN            NaN         NaN       NaN
#
#   seller_type transmission  owner
# 0         NaN          NaN    0.0
# 1         NaN          NaN    0.0
# 2         NaN          NaN    0.0
# 3         NaN          NaN    0.0
# ...

# %%
df.query('(selling_price < present_price) & (present_price < 5)')
# Out:
#      car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 3     wagon r  2011           2.85           4.15        5200    Petrol
# 10   alto 800  2017           2.85           3.60        2135    Petrol
# 20   alto k10  2016           2.85           3.95       25000    Petrol
# 23   alto k10  2014           2.50           3.46       45280    Petrol
# 24    wagon r  2013           2.90           4.41       56879    Petrol
# ..        ...   ...            ...            ...         ...       ...
# 225       i10  2011           2.70           4.60       22517    Petrol
# 227       i10  2011           2.55           4.43       57000    Petrol
# 236       eon  2016           3.10           4.43       11849    Petrol
# 239       eon  2012           2.00           4.43       23709    Petrol
# 248       i10  2013           4.00           4.60       30000    Petrol
#
#     seller_type transmission  owner
# 3        Dealer       Manual      0
# ...

# %%
#sorting by label
df.sort_index()
# Out:
#     car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     seller_type transmission  owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.sort_index(ascending=False)
# Out:
#     car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 300     brio  2016           5.30           5.90        5464    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 298     city  2009           3.35          11.00       87934    Petrol
# 297     brio  2015           4.00           5.90       60000    Petrol
# 296     city  2016           9.50          11.60       33988    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 4      swift  2014           4.60           6.87       42450    Diesel
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 0       ritz  2014           3.35           5.59       27000    Petrol
#
#     seller_type transmission  owner
# 300      Dealer       Manual      0
# 299      Dealer       Manual      0
# ...

# %%
#sort by column
df.sort_index(axis=1)
# Out:
#     car_name fuel_type  kms_driven  owner  present_price seller_type  \
# 0       ritz    Petrol       27000      0           5.59      Dealer
# 1        sx4    Diesel       43000      0           9.54      Dealer
# 2       ciaz    Petrol        6900      0           9.85      Dealer
# 3    wagon r    Petrol        5200      0           4.15      Dealer
# 4      swift    Diesel       42450      0           6.87      Dealer
# ..       ...       ...         ...    ...            ...         ...
# 296     city    Diesel       33988      0          11.60      Dealer
# 297     brio    Petrol       60000      0           5.90      Dealer
# 298     city    Petrol       87934      0          11.00      Dealer
# 299     city    Diesel        9000      0          12.50      Dealer
# 300     brio    Petrol        5464      0           5.90      Dealer
#
#      selling_price transmission  year
# 0             3.35       Manual  2014
# 1             4.75       Manual  2013
# ...

# %%
df.sort_index(axis=0)
# Out:
#     car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     seller_type transmission  owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.sort_values(by=['year'],ascending=True)
# Out:
#                       car_name  year  selling_price  present_price  \
# 37                         800  2003           0.35           2.28
# 39                         sx4  2003           2.25           7.98
# 77                     corolla  2004           1.50          12.35
# 54                      innova  2005           2.75          10.21
# 84                      innova  2005           3.49          13.46
# ..                         ...   ...            ...            ...
# 104  Royal Enfield Classic 350  2017           1.35           1.47
# 265                       jazz  2017           6.50           8.70
# 66                      innova  2017          19.75          23.15
# 134         TVS Apache RTR 160  2017           0.65           0.81
# 5                vitara brezza  2018           9.25           9.83
#
#      kms_driven fuel_type seller_type transmission  owner
# 37       127000    Petrol  Individual       Manual      0
# ...

# %%
df.sort_values(by=['selling_price','present_price'],ascending=[True,True])
# Out:
#                car_name  year  selling_price  present_price  kms_driven  \
# 200    Bajaj Pulsar 150  2006           0.10           0.75       92233
# 199      Honda CB Shine  2007           0.12           0.58       53000
# 198  Bajaj Discover 125  2011           0.15           0.57       35000
# 197    Honda CB twister  2010           0.16           0.51       33000
# 196           Activa 3g  2008           0.17           0.52      500000
# ..                  ...   ...            ...            ...         ...
# 51             fortuner  2015          23.00          30.61       40000
# 93             fortuner  2015          23.00          30.61       40000
# 63             fortuner  2015          23.50          35.96       47000
# 64             fortuner  2017          33.00          36.23        6000
# 86         land cruiser  2010          35.00          92.60       78000
#
#     fuel_type seller_type transmission  owner
# 200    Petrol  Individual       Manual      0
# ...

# %%
df.sort_values(by=['year'],ascending=False)
# Out:
#                  car_name  year  selling_price  present_price  kms_driven  \
# 5           vitara brezza  2018           9.25           9.83        2071
# 208                   i20  2017           7.90           8.10        3435
# 52                 innova  2017          18.00          19.77       15000
# 129     Yamaha FZ S V 2.0  2017           0.78           0.84        5000
# 128  Honda CB Hornet 160R  2017           0.80           0.87        3000
# ..                    ...   ...            ...            ...         ...
# 92                 innova  2005           3.51          13.70       75000
# 54                 innova  2005           2.75          10.21       90000
# 77                corolla  2004           1.50          12.35      135154
# 39                    sx4  2003           2.25           7.98       62000
# 37                    800  2003           0.35           2.28      127000
#
#     fuel_type seller_type transmission  owner
# ...

# %%
df.sort_values(by=['selling_price','present_price'],ascending=[False,True])
# Out:
#                car_name  year  selling_price  present_price  kms_driven  \
# 86         land cruiser  2010          35.00          92.60       78000
# 64             fortuner  2017          33.00          36.23        6000
# 63             fortuner  2015          23.50          35.96       47000
# 82               innova  2017          23.00          25.39       15000
# 51             fortuner  2015          23.00          30.61       40000
# ..                  ...   ...            ...            ...         ...
# 196           Activa 3g  2008           0.17           0.52      500000
# 197    Honda CB twister  2010           0.16           0.51       33000
# 198  Bajaj Discover 125  2011           0.15           0.57       35000
# 199      Honda CB Shine  2007           0.12           0.58       53000
# 200    Bajaj Pulsar 150  2006           0.10           0.75       92233
#
#     fuel_type seller_type transmission  owner
# 86     Diesel      Dealer       Manual      0
# ...

# %%
df['seller_type'].count()
# Out:
# 301

# %%
df['selling_price'].sum()
# Out:
# 1403.0500000000002

# %%
df['selling_price'].std()
# Out:
# 5.082811556177804

# %%
df['selling_price'].abs()
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: selling_price, Length: 301, dtype: float64

# %%
df['selling_price'].prod()
# Out:
# 1.365152009445672e+119

# %%
df['selling_price'].cumprod()
# Out:
# 0       3.350000e+00
# 1       1.591250e+01
# 2       1.153656e+02
# 3       3.287920e+02
# 4       1.512443e+03
#            ...
# 296    1.671485e+116
# 297    6.685940e+116
# 298    2.239790e+117
# 299    2.575759e+118
# 300    1.365152e+119
# Name: selling_price, Length: 301, dtype: float64

# %%
df['selling_price'].cumsum()
# Out:
# 0         3.35
# 1         8.10
# 2        15.35
# 3        18.20
# 4        22.80
#         ...
# 296    1378.90
# 297    1382.90
# 298    1386.25
# 299    1397.75
# 300    1403.05
# Name: selling_price, Length: 301, dtype: float64

# %%
#percent change
df['selling_price'].pct_change()
# Out:
# 0           NaN
# 1      0.417910
# 2      0.526316
# 3     -0.606897
# 4      0.614035
#          ...
# 296    0.111111
# 297   -0.578947
# 298   -0.162500
# 299    2.432836
# 300   -0.539130
# Name: selling_price, Length: 301, dtype: float64

# %%
#covariance
df.cov()
# Out:
#                        year  selling_price  present_price    kms_driven  \
# year               8.361085       3.470617      -1.189364 -5.895887e+04
# selling_price      3.470617      25.834973      38.619337  5.768966e+03
# present_price     -1.189364      38.619337      74.720731  6.845447e+04
# kms_driven    -58958.869767    5768.965732   68454.466283  1.512190e+09
# owner             -0.130543      -0.111323       0.017266  8.601011e+02
#
#                     owner
# year            -0.130543
# selling_price   -0.111323
# present_price    0.017266
# kms_driven     860.101074
# owner            0.061462

# %%
#correlation
df.corr()
# Out:
#                    year  selling_price  present_price  kms_driven     owner
# year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# selling_price  0.236141       1.000000       0.878983    0.029187 -0.088344
# present_price -0.047584       0.878983       1.000000    0.203647  0.008057
# kms_driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
#variance
df.var()
# Out:
# year             8.361085e+00
# selling_price    2.583497e+01
# present_price    7.472073e+01
# kms_driven       1.512190e+09
# owner            6.146179e-02
# dtype: float64

# %%
df.skew()
# Out:
# year            -1.246189
# selling_price    2.493422
# present_price    4.083150
# kms_driven       6.436013
# owner            7.616850
# dtype: float64

# %%
df.kurt()
# Out:
# year              1.533319
# selling_price     8.902970
# present_price    31.701024
# kms_driven       68.563569
# owner            73.325141
# dtype: float64

# %%
df.quantile()
# Out:
# year              2014.0
# selling_price        3.6
# present_price        6.4
# kms_driven       32000.0
# owner                0.0
# Name: 0.5, dtype: float64

# %%
df['seller_type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['seller_type'].nunique()
# Out:
# 2

# %%
df['present_price'].min()
# Out:
# 0.32

# %%
df['present_price'].max()
# Out:
# 92.6

# %%
df['present_price'].mode()
# Out:
# 0    9.4
# dtype: float64

# %%
df['present_price'].median()
# Out:
# 6.4

# %%
df['present_price'].mean()
# Out:
# 7.628471760797344

# %%
df['seller_type'].value_counts()
# Out:
# Dealer        195
# Individual    106
# Name: seller_type, dtype: int64

# %%
df['transmission'].value_counts(ascending=True)
# Out:
# Automatic     40
# Manual       261
# Name: transmission, dtype: int64

# %%
#series functionalities

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=301, step=1),
#  Index(['car_name', 'year', 'selling_price', 'present_price', 'kms_driven',
#         'fuel_type', 'seller_type', 'transmission', 'owner'],
#        dtype='object')]

# %%
df.columns
# Out:
# Index(['car_name', 'year', 'selling_price', 'present_price', 'kms_driven',
#        'fuel_type', 'seller_type', 'transmission', 'owner'],
#       dtype='object')

# %%
df['seller_type'].dtype
# Out:
# dtype('O')

# %%
df['seller_type'].empty
# Out:
# False

# %%
df['seller_type'].ndim
# Out:
# 1

# %%
df['seller_type'].size
# Out:
# 301

# %%
df['seller_type'].values
# Out:
# array(['Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Individual', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Individual', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Individual',
#        'Individual', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
#        'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer', 'Dealer',
# ...

# %%
df['seller_type'].head()
# Out:
# 0    Dealer
# 1    Dealer
# 2    Dealer
# 3    Dealer
# 4    Dealer
# Name: seller_type, dtype: object

# %%
df['seller_type'].tail()
# Out:
# 296    Dealer
# 297    Dealer
# 298    Dealer
# 299    Dealer
# 300    Dealer
# Name: seller_type, dtype: object

# %%
#dataframe functionalities - remain same as above plus the one below

# %%
df.T
# Out:
#                   0       1       2        3       4              5       6    \
# car_name         ritz     sx4    ciaz  wagon r   swift  vitara brezza    ciaz
# year             2014    2013    2017     2011    2014           2018    2015
# selling_price    3.35    4.75    7.25     2.85     4.6           9.25    6.75
# present_price    5.59    9.54    9.85     4.15    6.87           9.83    8.12
# kms_driven      27000   43000    6900     5200   42450           2071   18796
# fuel_type      Petrol  Diesel  Petrol   Petrol  Diesel         Diesel  Petrol
# seller_type    Dealer  Dealer  Dealer   Dealer  Dealer         Dealer  Dealer
# transmission   Manual  Manual  Manual   Manual  Manual         Manual  Manual
# owner               0       0       0        0       0              0       0
#
#                    7       8       9    ...     291     292     293     294  \
# car_name       s cross    ciaz    ciaz  ...    brio    jazz    city   amaze
# ...

# %%
lst = [['Arunda',23],['Sasikala',52],['Ambaal',28],['Rajendran',58]]

# %%
df = pd.DataFrame(lst, columns = ['Name','Age'])
print(df)
# Out:
#         Name  Age
# 0     Arunda   23
# 1   Sasikala   52
# 2     Ambaal   28
# 3  Rajendran   58

# %%
tup = [('Tara',22),('Riya',22),('Sahiti',21)]

# %%
df = pd.DataFrame(tup,columns=['Friend name','Age'])

# %%
print(df)
# Out:
#   Friend name  Age
# 0        Tara   22
# 1        Riya   22
# 2      Sahiti   21

# %%
df.pivot('Friend name','Age')
# Out:
# Empty DataFrame
# Columns: []
# Index: [Riya, Sahiti, Tara]

# %%
dit = [{'Name':'Arunda','Age':23},{'Name':'Sidharth','Age':22}]

# %%
ditdf = pd.DataFrame.from_dict(dit)

# %%
ditdf
# Out:
#        Name  Age
# 0    Arunda   23
# 1  Sidharth   22

# %%
dfdit = pd.DataFrame(dit, index = [1,2])

# %%
dfdit
# Out:
#        Name  Age
# 1    Arunda   23
# 2  Sidharth   22
